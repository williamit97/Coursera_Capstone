# %% [markdown]
# # Machine Learning to find locations to open an African street food restaurant in Paris

# %% [markdown]
# #### Sanchez William

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# #### In order to complete this Capstone project, I am going to carry out a fictitious project where I will help a future restaurant owner to find out in which neighbourhood, borough of Paris, it would be interesting to set up his restaurant. Indeed, this entrepreneur, restaurateur has an ambitious project. He wants to introduce African street food with new and delicious recipes.
# #### Indeed, Paris is a very touristy city and he is convinced that he will be able to spread the African street food culture throughout the world. Paris is a multicultural city recognised throughout the world.
# #### After having carried out an Business Plan and in particular a market study, this entrepreneur wishes to establish himself in a neighbourhood where African cuisine is popular. Thus, my study is a key step for this entrepreneur, because the success of his project depends on my estimation of the location of his future restaurant.

# %% [markdown]
# ## 2. Business Problem

# %% [markdown]
# #### The aim of this Capstone project is to help an entrepreneur find the best location in Paris, France, so that his restaurant can be best established and his project can be as viable and profitable as possible. On a larger scale, this project may help stakeholders wanting to create African street food restaurants.

# %% [markdown]
# ## 3. Data

# %% [markdown]
# #### We are going to need geographic location data for the city of Paris, France. We will use a database including postcodes, borough in order to better use the Foursquare API and to determine the most popular venues categories.
# #### In order to solve this problem we will need this data :

# %% [markdown]
#    ### 3.1 Paris Neighbourhood Data

# %% [markdown]
# #### [JSON data](https://www.data.gouv.fr/fr/datasets/r/e88c6fda-1d09-42a0-a069-606d3259114e)

# %% [markdown]
# #### The JSON file has data about all the neighbourhoods in France, we limit it to Paris.

# %% [markdown]
# - Paris Data
#   * postal_code : Postal codes for France
#   * nom_comm : Name of Neighbourhoods in France
#   * nom_dept : Name of the boroughs, equivalent to towns in France
#   * geo_point_2d : Tuple containing the latitude and longitude of the Neighbourhoods.

# %% [markdown]
# ### 3.2 Foursquare API Data

# %% [markdown]
# #### The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the postcodes. The information obtained per venue as follows:

# %% [markdown]
# - Foursquare API Data
#   * Neighbourhood : Name of the Neighbourhood
#   * Neighbourhood Latitude : Latitude of the Neighbourhood
